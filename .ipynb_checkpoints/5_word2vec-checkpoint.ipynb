# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  ##print("Start:")  
  #print(buffer)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    #print(buffer)
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.578541
# Nearest to his: leftmost, infoplease, inflict, connors, foraminifera, cays, erbium, capone,
# Nearest to an: jam, journeys, tremont, mimics, forgetfulness, politically, reloaded, congregational,
# Nearest to than: loy, rawls, frazier, renounce, hippopotamus, woodward, spit, negotiator,
# Nearest to are: trapdoor, alkaline, suzanne, gator, popes, realm, wally, poetess,
# Nearest to that: stuff, coppersmith, comprehensible, marcellinus, fujitsu, crucifixion, gopher, percussive,
# Nearest to if: thaler, merits, breech, challenger, tricyclic, rheumatism, yellowish, oscilloscope,
# Nearest to has: yang, polemical, qaida, ludo, whore, casuistry, monorail, linebarger,
# Nearest to up: italics, ombudsman, chic, student, heracleidae, libi, sixes, peuple,
# Nearest to seven: censorware, griffiths, zoomed, cho, reflected, psychological, menander, obstinate,
# Nearest to two: esa, towns, unconquered, camus, competed, joni, developers, neologism,
# Nearest to he: yakovlev, nuevo, divergences, pentecost, pardon, dhtml, flamboyant, devoting,
# Nearest to which: apartments, idealism, overnight, kannapolis, peregrine, orson, hetzel, benediction,
# Nearest to some: triggers, praetorius, boxers, bodmin, angry, beauvoir, abandonware, eon,
# Nearest to is: mizrahi, indigenous, aalborg, carniola, accessing, andronicus, pupil, wage,
# Nearest to were: midwest, thrive, debate, hydrated, wu, thing, bought, mush,
# Nearest to no: undetectable, librettist, melody, kangaroo, traded, jong, basenji, gershwin,
# Average loss at step 2000: 4.372220
# Average loss at step 4000: 3.868030
# Average loss at step 6000: 3.785754
# Average loss at step 8000: 3.689777
# Average loss at step 10000: 3.619926
# Nearest to his: their, the, s, her, its, botha, infoplease, erbium,
# Nearest to an: describes, stanley, jam, arnold, the, madras, dihedral, drags,
# Nearest to than: or, woodward, stocking, episcopalian, historian, spit, metallurgy, tsui,
# Nearest to are: were, is, have, trans, can, could, be, but,
# Nearest to that: disappointing, which, dissolving, babysitter, it, rathaus, romance, namesake,
# Nearest to if: ccp, maradns, arteries, ghazi, commodus, merits, retroactive, boxes,
# Nearest to has: had, was, have, is, polemical, monorail, spence, advanced,
# Nearest to up: fubar, nicobar, denser, lacrosse, arisen, plethora, minibuses, ajmer,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to two: three, five, four, six, eight, zero, seven, nine,
# Nearest to he: it, they, she, who, i, ananda, nugget, schwann,
# Nearest to which: it, this, also, benediction, lincoln, that, reacting, eglise,
# Nearest to some: many, triggers, glick, weekdays, phosphor, angry, other, these,
# Nearest to is: was, are, has, but, be, proctor, wen, carbohydrate,
# Nearest to were: are, was, have, be, peoples, receivers, bishkek, interacting,
# Nearest to no: traded, madhya, undetectable, it, kangaroo, librettist, jong, schiller,
# Average loss at step 12000: 3.605414
# Average loss at step 14000: 3.569357
# Average loss at step 16000: 3.413370
# Average loss at step 18000: 3.456287
# Average loss at step 20000: 3.544114
# Nearest to his: their, her, its, the, politicians, botha, halides, our,
# Nearest to an: jam, the, arnold, gerald, stanley, exceptionally, figurehead, purview,
# Nearest to than: or, woodward, stocking, episcopalian, savile, catalogs, sheikh, duesberg,
# Nearest to are: were, is, have, while, was, can, trans, surges,
# Nearest to that: which, but, bohdan, it, this, stored, accountants, where,
# Nearest to if: but, whether, maradns, ghazi, though, photographers, assuming, middleweight,
# Nearest to has: had, was, have, is, polemical, alludes, monorail, overwhelming,
# Nearest to up: nicobar, fubar, lacrosse, him, wasting, arisen, experiencing, denser,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to two: five, three, six, four, one, seven, eight, zero,
# Nearest to he: it, they, she, who, there, never, which, engraved,
# Nearest to which: this, that, it, who, also, and, what, but,
# Nearest to some: many, these, several, their, all, other, most, glick,
# Nearest to is: was, has, are, does, but, be, revealed, undated,
# Nearest to were: are, was, have, be, had, bishkek, been, is,
# Nearest to no: traded, ons, madhya, schiller, it, briefing, burgesses, graphics,
# Average loss at step 22000: 3.500744
# Average loss at step 24000: 3.489239
# Average loss at step 26000: 3.482782
# Average loss at step 28000: 3.477631
# Average loss at step 30000: 3.504152
# Nearest to his: their, her, its, the, s, politicians, running, my,
# Nearest to an: jam, exceptionally, arnold, colourless, sissy, wissenschaften, figurehead, saville,
# Nearest to than: woodward, or, inflating, much, stocking, savile, duesberg, spit,
# Nearest to are: were, have, is, while, be, include, abelard, ebbinghaus,
# Nearest to that: which, however, because, what, but, disappointing, rarely, this,
# Nearest to if: when, but, whether, though, however, although, photographers, barber,
# Nearest to has: had, have, is, was, alludes, polemical, escalated, stew,
# Nearest to up: him, them, wasting, minibuses, out, fubar, nicobar, experiencing,
# Nearest to seven: eight, five, four, six, nine, three, two, zero,
# Nearest to two: four, three, five, six, seven, one, eight, zero,
# Nearest to he: she, it, they, who, there, enclosures, ananda, never,
# Nearest to which: this, that, also, what, these, it, conical, usually,
# Nearest to some: many, these, several, their, all, the, various, other,
# Nearest to is: was, has, are, be, does, became, while, entheogens,
# Nearest to were: are, was, have, been, had, tiglath, be, by,
# Nearest to no: any, a, briefing, ons, madhya, inserted, traded, graphics,
# Average loss at step 32000: 3.502767
# Average loss at step 34000: 3.486158
# Average loss at step 36000: 3.453190
# Average loss at step 38000: 3.302582
# Average loss at step 40000: 3.433531
# Nearest to his: their, her, its, the, s, my, our, earls,
# Nearest to an: jam, arnold, hist, the, exceptionally, macao, politically, figurehead,
# Nearest to than: or, much, inflating, woodward, catalogs, duesberg, hippopotamus, stocking,
# Nearest to are: were, have, is, include, but, qed, while, equating,
# Nearest to that: which, however, what, because, this, stored, widens, but,
# Nearest to if: when, where, is, though, but, and, barber, so,
# Nearest to has: had, have, is, was, since, naguib, escalated, liturgics,
# Nearest to up: him, out, them, wasting, minibuses, either, fubar, lacrosse,
# Nearest to seven: five, eight, six, nine, four, three, zero, one,
# Nearest to two: four, three, five, six, seven, one, eight, zero,
# Nearest to he: she, it, they, there, who, never, i, we,
# Nearest to which: that, this, also, who, what, usually, it, these,
# Nearest to some: many, any, these, several, their, this, methods, such,
# Nearest to is: was, has, are, be, if, daylights, does, brisk,
# Nearest to were: are, was, have, had, been, be, those, being,
# Nearest to no: any, ons, helsing, leprosy, ever, briefing, inserted, madhya,
# Average loss at step 42000: 3.437859
# Average loss at step 44000: 3.451884
# Average loss at step 46000: 3.448102
# Average loss at step 48000: 3.355721
# Average loss at step 50000: 3.384326
# Nearest to his: their, her, its, my, the, our, your, s,
# Nearest to an: informative, exceptionally, reloaded, macao, hives, hist, chiefly, adware,
# Nearest to than: or, much, woodward, inflating, cy, but, catalogs, duesberg,
# Nearest to are: were, have, is, be, include, gotha, those, these,
# Nearest to that: which, however, what, but, babysitter, client, romance, this,
# Nearest to if: when, where, though, barber, so, while, although, photographers,
# Nearest to has: had, have, was, is, since, liturgics, limewire, naguib,
# Nearest to up: out, him, them, off, wasting, down, experiencing, fubar,
# Nearest to seven: eight, six, four, nine, three, five, zero, two,
# Nearest to two: three, four, six, one, five, seven, eight, nine,
# Nearest to he: she, it, they, who, there, we, morphisms, this,
# Nearest to which: this, that, also, what, who, usually, these, but,
# Nearest to some: many, several, these, various, both, those, their, critics,
# Nearest to is: was, has, are, becomes, entheogens, be, contains, although,
# Nearest to were: are, was, have, be, had, been, those, corinne,
# Nearest to no: any, ons, little, cerium, leprosy, gf, briefing, sobieski,
# Average loss at step 52000: 3.438413
# Average loss at step 54000: 3.431858
# Average loss at step 56000: 3.440747
# Average loss at step 58000: 3.402130
# Average loss at step 60000: 3.397835
# Nearest to his: her, their, its, my, your, our, the, politicians,
# Nearest to an: qaddafi, jam, informative, exceptionally, earhart, reloaded, fully, hist,
# Nearest to than: or, much, but, inflating, and, blew, catalogs, woodward,
# Nearest to are: were, have, is, include, be, these, including, those,
# Nearest to that: which, however, this, what, there, toilet, where, it,
# Nearest to if: when, where, though, although, so, whether, barber, before,
# Nearest to has: had, have, was, is, liturgics, eridu, patrimony, since,
# Nearest to up: out, him, them, off, down, wasting, away, fubar,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to two: three, five, four, six, one, eight, seven, zero,
# Nearest to he: she, it, they, who, there, we, soon, i,
# Nearest to which: that, this, what, these, however, but, katzenjammer, there,
# Nearest to some: many, several, these, most, their, those, each, the,
# Nearest to is: was, has, are, be, contains, although, does, seems,
# Nearest to were: are, was, have, had, be, those, tiglath, been,
# Nearest to no: any, little, ons, gf, a, only, albers, anisotropies,
# Average loss at step 62000: 3.240833
# Average loss at step 64000: 3.255371
# Average loss at step 66000: 3.403243
# Average loss at step 68000: 3.395236
# Average loss at step 70000: 3.358696
# Nearest to his: her, their, its, my, your, our, the, him,
# Nearest to an: qaddafi, hist, earhart, jam, exceptionally, macao, colourless, the,
# Nearest to than: much, or, undisclosed, lob, blew, inflating, but, and,
# Nearest to are: were, have, is, include, including, these, contain, although,
# Nearest to that: which, however, what, this, but, where, often, also,
# Nearest to if: when, though, where, although, however, while, so, before,
# Nearest to has: had, have, is, was, since, liturgics, eridu, having,
# Nearest to up: out, off, them, down, him, back, wasting, fubar,
# Nearest to seven: six, eight, four, nine, five, three, one, zero,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to he: she, it, they, we, there, soon, who, never,
# Nearest to which: that, this, also, but, these, however, what, and,
# Nearest to some: many, several, these, various, most, all, their, both,
# Nearest to is: was, has, are, be, although, entheogens, becomes, seems,
# Nearest to were: are, was, have, had, be, although, including, salom,
# Nearest to no: any, little, ons, there, dect, anisotropies, albers, kaiju,
# Average loss at step 72000: 3.373863
# Average loss at step 74000: 3.348014
# Average loss at step 76000: 3.322411
# Average loss at step 78000: 3.351732
# Average loss at step 80000: 3.378701
# Nearest to his: her, their, its, my, your, our, the, earls,
# Nearest to an: qaddafi, colourless, macao, exceptionally, rowboat, hives, jam, ayub,
# Nearest to than: much, or, inflating, but, purifying, catalogs, while, undisclosed,
# Nearest to are: were, have, include, is, contain, these, although, including,
# Nearest to that: which, however, where, dudley, this, aforementioned, prim, sherwood,
# Nearest to if: when, though, where, before, although, because, so, however,
# Nearest to has: had, have, is, was, since, liturgics, although, eridu,
# Nearest to up: out, off, down, them, him, wasting, back, away,
# Nearest to seven: eight, six, five, four, nine, three, two, one,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to he: she, it, they, there, we, who, soon, never,
# Nearest to which: that, this, also, usually, often, but, sensei, where,
# Nearest to some: many, several, these, various, most, both, prefaces, certain,
# Nearest to is: was, has, are, became, be, although, uses, rethinking,
# Nearest to were: are, had, was, have, although, those, tiglath, including,
# Nearest to no: little, any, ons, kaiju, there, judaizers, anisotropies, dect,
# Average loss at step 82000: 3.405932
# Average loss at step 84000: 3.409860
# Average loss at step 86000: 3.390380
# Average loss at step 88000: 3.352794
# Average loss at step 90000: 3.362529
# Nearest to his: her, their, its, my, your, our, the, him,
# Nearest to an: colourless, qaddafi, exceptionally, intersected, hist, hives, earhart, sidi,
# Nearest to than: much, inflating, catalogs, purifying, hippopotamus, undisclosed, wharf, fini,
# Nearest to are: were, is, these, have, include, those, although, contain,
# Nearest to that: which, however, marcellinus, what, dudley, gos, poking, instead,
# Nearest to if: when, though, where, since, barber, so, before, although,
# Nearest to has: had, have, is, was, having, since, contains, omnium,
# Nearest to up: out, off, down, him, them, back, away, wasting,
# Nearest to seven: five, eight, four, six, nine, three, two, one,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to he: she, it, they, there, who, soon, we, subsequently,
# Nearest to which: that, this, also, usually, what, both, often, but,
# Nearest to some: many, several, these, all, both, numerous, various, any,
# Nearest to is: was, are, has, be, becomes, although, entheogens, if,
# Nearest to were: are, had, while, was, have, although, those, tiglath,
# Nearest to no: any, little, already, ons, dect, kaiju, briefing, there,
# Average loss at step 92000: 3.396960
# Average loss at step 94000: 3.251215
# Average loss at step 96000: 3.362221
# Average loss at step 98000: 3.245274
# Average loss at step 100000: 3.357688
# Nearest to his: her, their, my, our, its, your, the, s,
# Nearest to an: exceptionally, kerenyi, another, earhart, hives, proconsular, hermits, jam,
# Nearest to than: or, much, catalogs, inflating, merits, undisclosed, slightly, wharf,
# Nearest to are: were, have, these, those, include, although, is, be,
# Nearest to that: which, what, however, who, disappointing, dudley, gos, but,
# Nearest to if: when, though, where, because, since, while, so, before,
# Nearest to has: had, have, is, was, since, having, hutton, contains,
# Nearest to up: off, out, back, down, him, them, away, either,
# Nearest to seven: eight, six, five, four, nine, three, two, zero,
# Nearest to two: four, three, five, six, eight, one, seven, zero,
# Nearest to he: she, it, they, who, there, we, never, this,
# Nearest to which: that, this, what, usually, also, these, it, but,
# Nearest to some: many, several, these, any, certain, various, all, numerous,
# Nearest to is: was, has, became, seems, be, are, kaliningrad, being,
# Nearest to were: are, have, was, these, had, those, tiglath, appear,
# Nearest to no: any, little, another, kaiju, already, dect, jadavpur, anthropos,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Idea from https://github.com/budmitr/udacity-deep-learning/blob/master/5_word2vec.ipynb

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    # Swap data and labels, does this really work?
    batch_labels, batch_data = generate_batch(
      batch_size, num_skips, skip_window)
    batch_data = batch_data.reshape((batch_size,))
    batch_labels = batch_labels.reshape((batch_size, 1))
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.708628
# Nearest to his: allophone, monotonicity, prions, gow, realaudio, lansbury, divorce, coverage,
# Nearest to an: energy, verhofstadt, shires, isolation, wrestlemania, livingston, troughs, stanhope,
# Nearest to than: mica, vanished, gyeonggi, flies, glastonbury, attar, hike, storytellers,
# Nearest to are: elegies, once, monophosphate, moment, unjustly, wage, marceau, antoni,
# Nearest to that: race, aarseth, syntactical, hippocampus, fucked, hakama, packaged, tenji,
# Nearest to if: guilt, printing, hieroglyphs, delved, mason, shower, contain, campy,
# Nearest to has: centimetres, plaintexts, pretext, ili, gustloff, prefaced, ellington, unconvinced,
# Nearest to up: quinine, jud, sonorants, trips, brp, reaper, autoerotic, alban,
# Nearest to seven: flatted, strat, verdicts, copperfield, schoolteacher, microarchitecture, mysticeti, sunni,
# Nearest to two: stencil, kaos, zambia, emanuel, capablanca, hat, underdeveloped, sanitarium,
# Nearest to he: andrews, prodigy, wikimedia, endogamous, sagrada, pigment, missiles, cadets,
# Nearest to which: modality, prices, conflicts, pcd, familia, diaries, degenerate, cy,
# Nearest to some: seljuk, ellery, boosted, rale, axum, degradation, dimer, bankrupt,
# Nearest to is: embodies, stilgar, insiders, pay, liquidated, recreating, ailing, pondering,
# Nearest to were: geek, rationalization, wang, looms, wants, fanfic, diaspora, workman,
# Nearest to no: inuit, kis, huntingford, plate, caspar, zander, amazingly, stuffing,
# Average loss at step 2000: 4.380333
# Average loss at step 4000: 3.880951
# Average loss at step 6000: 3.799591
# Average loss at step 8000: 3.766688
# Average loss at step 10000: 3.622330
# Nearest to his: their, its, the, coverage, her, chondrites, pressed, gow,
# Nearest to an: federated, stanhope, wrestlemania, busway, shires, ascalon, betty, oldenburg,
# Nearest to than: mica, gyeonggi, glastonbury, regi, circulating, iambic, storytellers, eszterh,
# Nearest to are: were, is, have, was, by, attachment, monument, wage,
# Nearest to that: which, this, continental, but, also, schoolgirl, unabomber, bundles,
# Nearest to if: atherosclerosis, could, printing, guernica, hieroglyphs, pragmatism, build, guilt,
# Nearest to has: is, had, have, was, unconvinced, handbook, engagement, parodies,
# Nearest to up: revolver, them, reaper, eschewing, jud, lagoon, monomorphism, buckets,
# Nearest to seven: six, four, eight, five, nine, three, one, zero,
# Nearest to two: three, one, four, six, five, seven, eight, zero,
# Nearest to he: it, she, who, too, they, designate, were, wonderswan,
# Nearest to which: that, this, it, also, there, taxis, degenerate, dunn,
# Nearest to some: many, ism, these, colony, stallions, its, ellery, hypocrisy,
# Nearest to is: was, are, has, halal, be, plentiful, by, were,
# Nearest to were: are, was, have, cker, is, wang, slaying, clan,
# Nearest to no: plate, stuffing, scrimmage, often, musa, disenfranchised, kajang, pixel,
# Average loss at step 12000: 3.583909
# Average loss at step 14000: 3.613027
# Average loss at step 16000: 3.583178
# Average loss at step 18000: 3.572561
# Average loss at step 20000: 3.548736
# Nearest to his: their, her, its, the, demography, s, pressed, this,
# Nearest to an: federated, busway, airfields, stanhope, lugdunum, the, occurs, terrified,
# Nearest to than: glastonbury, gyeonggi, mica, or, regi, iambic, circulating, much,
# Nearest to are: were, is, have, wage, these, workday, cambrian, mohenjo,
# Nearest to that: which, but, this, who, gritty, however, what, hanson,
# Nearest to if: when, could, where, will, atherosclerosis, telephony, ratchet, overran,
# Nearest to has: had, have, was, is, engagement, varese, dirt, seditious,
# Nearest to up: them, him, buckets, reaper, down, keepers, out, revolver,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to two: three, four, five, six, eight, one, seven, nine,
# Nearest to he: she, it, they, who, there, this, headlights, wonderswan,
# Nearest to which: that, this, also, it, who, what, there, schoolgirl,
# Nearest to some: many, these, all, their, several, esquerra, different, most,
# Nearest to is: was, are, has, esaf, barks, halal, eleonora, chipset,
# Nearest to were: are, was, have, cker, had, by, be, cambrian,
# Nearest to no: plate, stuffing, scrimmage, disenfranchised, ever, musa, any, jan,
# Average loss at step 22000: 3.529228
# Average loss at step 24000: 3.442225
# Average loss at step 26000: 3.418259
# Average loss at step 28000: 3.475274
# Average loss at step 30000: 3.410259
# Nearest to his: her, their, its, the, my, geodesic, gow, chondrites,
# Nearest to an: busway, airfields, federated, atypical, ascalon, retreated, stanhope, rations,
# Nearest to than: or, mica, glastonbury, much, gyeonggi, iambic, brace, circulating,
# Nearest to are: were, is, have, cambrian, be, wage, ashford, with,
# Nearest to that: which, where, this, however, fragmentary, then, hippocampus, what,
# Nearest to if: when, where, atherosclerosis, could, because, is, will, overran,
# Nearest to has: had, have, is, was, engagement, thebaid, concerti, struma,
# Nearest to up: them, down, him, out, reaper, eschewing, off, monomorphism,
# Nearest to seven: eight, six, nine, five, four, three, two, zero,
# Nearest to two: four, three, six, seven, five, eight, zero, nine,
# Nearest to he: she, it, they, who, there, never, headlights, barnum,
# Nearest to which: that, this, it, what, there, who, also, but,
# Nearest to some: many, these, several, all, such, their, each, most,
# Nearest to is: was, has, are, be, scoreless, if, eleonora, had,
# Nearest to were: are, had, have, was, be, been, mechanic, clan,
# Nearest to no: plate, musa, any, disenfranchised, ever, slates, only, another,
# Average loss at step 32000: 3.421779
# Average loss at step 34000: 3.440668
# Average loss at step 36000: 3.361112
# Average loss at step 38000: 3.493091
# Average loss at step 40000: 3.449292
# Nearest to his: her, their, its, my, the, s, demography, gow,
# Nearest to an: ascalon, the, another, airfields, rations, isolation, stanhope, busway,
# Nearest to than: or, mica, glastonbury, much, iambic, qwerty, way, gyeonggi,
# Nearest to are: were, have, is, these, caravan, include, bodybuilders, wage,
# Nearest to that: which, however, this, what, where, but, it, fragmentary,
# Nearest to if: when, where, atherosclerosis, before, because, is, though, for,
# Nearest to has: had, have, was, is, since, criticized, homicides, clumps,
# Nearest to up: them, down, him, off, out, reaper, juniors, eschewing,
# Nearest to seven: eight, six, nine, four, five, zero, two, three,
# Nearest to two: five, three, six, zero, seven, eight, four, one,
# Nearest to he: she, it, they, who, there, never, later, batgirl,
# Nearest to which: that, this, also, what, it, who, but, there,
# Nearest to some: many, these, several, all, their, this, both, any,
# Nearest to is: was, has, seems, are, esaf, be, if, does,
# Nearest to were: are, was, have, had, be, been, cker, caravan,
# Nearest to no: plate, musa, any, another, a, disenfranchised, it, ernie,
# Average loss at step 42000: 3.429146
# Average loss at step 44000: 3.277770
# Average loss at step 46000: 3.415432
# Average loss at step 48000: 3.431306
# Average loss at step 50000: 3.436585
# Nearest to his: their, her, its, my, the, demography, our, masuria,
# Nearest to an: ascalon, atypical, terrified, evolved, airfields, rations, retreated, concentrate,
# Nearest to than: or, much, glastonbury, butane, gain, mica, screen, gyeonggi,
# Nearest to are: were, is, have, including, include, these, dignitaries, although,
# Nearest to that: however, which, what, where, this, hippocampus, gazing, wheelbase,
# Nearest to if: when, where, because, before, atherosclerosis, for, will, utterance,
# Nearest to has: had, have, was, is, since, struma, richter, unethical,
# Nearest to up: down, out, off, him, them, juniors, reaper, back,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to two: three, five, four, six, seven, one, eight, zero,
# Nearest to he: she, it, they, who, there, never, we, nasser,
# Nearest to which: this, that, what, who, it, also, often, there,
# Nearest to some: many, several, these, any, their, both, all, most,
# Nearest to is: was, has, are, became, be, barks, esaf, were,
# Nearest to were: are, was, have, caravan, had, maior, those, been,
# Nearest to no: any, plate, musa, ties, only, disenfranchised, another, ernie,
# Average loss at step 52000: 3.456116
# Average loss at step 54000: 3.433249
# Average loss at step 56000: 3.404398
# Average loss at step 58000: 3.282907
# Average loss at step 60000: 3.378720
# Nearest to his: her, their, its, my, the, our, demography, whose,
# Nearest to an: evolved, rations, another, haas, airfields, veritable, busway, atypical,
# Nearest to than: or, much, butane, glastonbury, tokens, dustin, bumps, irreplaceable,
# Nearest to are: were, include, have, including, is, although, bodybuilders, dignitaries,
# Nearest to that: which, however, what, this, where, fragmentary, how, scraping,
# Nearest to if: when, where, though, is, before, will, could, because,
# Nearest to has: had, have, is, was, collisions, sped, does, having,
# Nearest to up: down, off, out, him, them, back, together, reaper,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to two: three, four, five, eight, seven, six, one, nine,
# Nearest to he: she, it, they, who, there, never, nasser, eventually,
# Nearest to which: that, this, what, who, these, it, also, however,
# Nearest to some: many, these, several, all, both, certain, any, their,
# Nearest to is: was, has, are, although, makes, be, if, does,
# Nearest to were: are, was, those, caravan, had, maior, have, including,
# Nearest to no: any, disenfranchised, ties, plate, only, musa, another, triumph,
# Average loss at step 62000: 3.438728
# Average loss at step 64000: 3.366646
# Average loss at step 66000: 3.343947
# Average loss at step 68000: 3.385332
# Average loss at step 70000: 3.371985
# Nearest to his: her, their, its, my, the, demography, our, s,
# Nearest to an: another, airfields, atypical, hemispheric, rations, veritable, busway, supergroup,
# Nearest to than: or, much, butane, glastonbury, tsiolkovsky, irreplaceable, fixes, pointer,
# Nearest to are: were, is, include, have, although, including, be, impediment,
# Nearest to that: which, however, what, but, when, dect, where, trumped,
# Nearest to if: when, though, before, where, is, while, although, after,
# Nearest to has: had, have, is, was, although, imperatives, does, conformational,
# Nearest to up: down, off, out, him, them, together, back, offshoot,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to two: three, five, four, eight, six, seven, one, nine,
# Nearest to he: she, it, they, there, who, never, later, we,
# Nearest to which: this, that, what, who, taxis, also, arb, it,
# Nearest to some: many, these, several, all, certain, both, any, most,
# Nearest to is: was, are, has, if, although, became, infirmary, becomes,
# Nearest to were: are, was, have, caravan, had, those, been, although,
# Nearest to no: any, disenfranchised, plate, musa, another, only, little, cf,
# Average loss at step 72000: 3.401180
# Average loss at step 74000: 3.387175
# Average loss at step 76000: 3.350737
# Average loss at step 78000: 3.236158
# Average loss at step 80000: 3.375176
# Nearest to his: her, their, its, my, the, demography, our, your,
# Nearest to an: airfields, the, atypical, another, ascalon, evolved, supergroup, veritable,
# Nearest to than: or, much, and, glastonbury, advocating, tsiolkovsky, no, toothpaste,
# Nearest to are: were, have, is, include, including, although, be, wage,
# Nearest to that: which, however, what, but, evolutionarily, this, hanson, vouchers,
# Nearest to if: when, where, though, then, before, is, while, for,
# Nearest to has: had, have, is, was, since, although, conformational, schneider,
# Nearest to up: down, off, out, back, them, him, together, binds,
# Nearest to seven: six, nine, five, eight, four, three, zero, two,
# Nearest to two: three, six, one, four, five, seven, zero, eight,
# Nearest to he: she, it, they, there, who, never, yag, we,
# Nearest to which: this, that, what, usually, often, also, who, but,
# Nearest to some: many, several, these, certain, any, both, all, this,
# Nearest to is: was, has, are, be, esaf, if, infirmary, becomes,
# Nearest to were: are, was, have, had, caravan, those, these, maior,
# Nearest to no: any, disenfranchised, little, only, another, lucy, since, plate,
# Average loss at step 82000: 3.293859
# Average loss at step 84000: 3.343067
# Average loss at step 86000: 3.342971
# Average loss at step 88000: 3.319953
# Average loss at step 90000: 3.243337
# Nearest to his: her, their, its, my, the, demography, your, s,
# Nearest to an: rations, atypical, another, kenilworth, airfields, federated, supergroup, veritable,
# Nearest to than: or, no, much, glastonbury, irreplaceable, mata, pointer, storytellers,
# Nearest to are: were, is, include, have, including, while, although, lumped,
# Nearest to that: which, however, what, cassini, this, pett, grizzly, railtrack,
# Nearest to if: when, though, before, although, where, did, because, while,
# Nearest to has: had, have, is, was, since, collisions, stimulants, sphincter,
# Nearest to up: off, down, out, back, him, them, together, offshoot,
# Nearest to seven: six, eight, four, nine, five, three, zero, two,
# Nearest to two: three, five, four, six, seven, zero, eight, one,
# Nearest to he: she, it, they, there, who, never, we, but,
# Nearest to which: that, this, also, what, who, often, taxis, usually,
# Nearest to some: many, several, certain, these, all, those, most, this,
# Nearest to is: was, has, although, are, barks, becomes, esaf, canby,
# Nearest to were: are, was, had, have, these, caravan, being, those,
# Nearest to no: any, little, disenfranchised, than, ties, slips, ernie, banda,
# Average loss at step 92000: 2.739562
# Average loss at step 94000: 3.103585
# Average loss at step 96000: 3.066927
# Average loss at step 98000: 3.219990
# Average loss at step 100000: 3.282185
# Nearest to his: her, their, its, my, whose, the, your, demography,
# Nearest to an: atypical, rations, supergroup, another, airfields, busway, haas, hemispheric,
# Nearest to than: or, much, no, pointer, sith, mata, glastonbury, bumps,
# Nearest to are: were, include, is, have, those, while, these, dignitaries,
# Nearest to that: which, however, what, this, where, often, cassini, haemophilia,
# Nearest to if: when, though, did, before, where, but, although, because,
# Nearest to has: had, have, was, is, since, although, ltv, having,
# Nearest to up: down, off, out, them, together, him, back, offshoot,
# Nearest to seven: six, eight, four, nine, five, three, zero, two,
# Nearest to two: three, five, four, six, seven, one, zero, eight,
# Nearest to he: she, they, it, there, but, who, never, we,
# Nearest to which: that, this, what, these, also, and, who, often,
# Nearest to some: many, several, these, both, certain, their, any, those,
# Nearest to is: was, has, although, are, infirmary, contains, seems, makes,
# Nearest to were: are, have, those, was, these, had, caravan, while,
# Nearest to no: any, little, disenfranchised, than, slips, actuality, ernie, another,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# 'Continuous bag of words' reverses skip-gram, more or less. So instead of:

# %% [markdown]
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']

# %% [markdown]
# You should get:
#
# with bag_window = 1: (batch_size = 4)
#
# batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#
# labels: ['originated', 'as', 'a', 'term']

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, bag_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * bag_window + 1
  buffer = [] #collections.deque(maxlen=span)
  # Fill buffer with span of words, i.e. target word plus bag_window of words on each side, for first word
  for i in range(span):
    buffer.append(data[data_index+i])
  
  data_index = (data_index + 1) % len(data) # Does this wrap around to the beginning?
  
  for i in range(batch_size):
    labels[i] = buffer.pop(bag_window) # Grab middle of buffer as our label
    batch[i] = buffer
    buffer = []
    for i in range(span):
        buffer.append(data[data_index+i])
    
    data_index = (data_index + 1) % len(data)

  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']
