# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.621154
# Nearest to about: darya, stockhausen, dominica, terrence, reprimanded, guano, feathered, otherworldly,
# Nearest to are: forbade, sleeps, passenger, anubis, lightning, omphalos, magdalen, urbe,
# Nearest to it: there, elf, undertones, burgos, hammerheads, epidemiology, omar, abbey,
# Nearest to other: participate, premiere, matres, consultants, haida, vesuvius, hematite, haznawi,
# Nearest to often: trojan, zacharias, andamanese, ministers, outdoors, ariadne, abraham, turkmenistan,
# Nearest to is: snes, ischemic, acidity, trombones, yew, dynamo, hitherto, bassoons,
# Nearest to i: crusades, worsen, gentler, rsa, diaphragm, cardinal, stilicho, personae,
# Nearest to they: inline, chydenius, leh, emery, vidal, blossoms, deficiencies, vesicles,
# Nearest to on: buddhahood, amg, moroccan, dwarves, metaphase, referendums, hijacked, esteemed,
# Nearest to system: nara, norwood, usurped, bicycle, outrageous, duck, frisch, gions,
# Nearest to has: ergative, tips, incongruous, faber, dock, onwards, unlucky, compiler,
# Nearest to who: zbigniew, cmd, kristina, maturation, compilation, paternal, adopting, phoenician,
# Nearest to which: crtc, executes, vytautas, cleanup, liliales, carpet, posthumus, limitless,
# Nearest to six: assures, fidesz, outcast, oral, depicting, treasuries, tolkien, wiltshire,
# Nearest to an: herself, doubt, allude, presenters, frication, easing, cidre, fdp,
# Nearest to no: bankruptcy, trousers, grating, bah, eisa, justifiable, sacu, cello,
# Average loss at step 2000: 4.359320
# Average loss at step 4000: 3.859926
# Average loss at step 6000: 3.788985
# Average loss at step 8000: 3.683140
# Average loss at step 10000: 3.613083
# Nearest to about: darya, classified, aroma, stockhausen, paper, somber, hover, terrence,
# Nearest to are: were, is, have, news, was, chattanooga, prophets, although,
# Nearest to it: he, there, this, that, which, they, sherwood, not,
# Nearest to other: premiere, iguana, participate, anything, haida, vesuvius, wealthy, matres,
# Nearest to often: also, sometimes, unsolvable, there, it, nave, hilversum, sondheim,
# Nearest to is: was, are, has, be, snes, if, warrants, foolish,
# Nearest to i: whither, archives, diaphragm, he, cardinal, worsen, actually, crusades,
# Nearest to they: he, it, inline, we, deficiencies, inductor, there, would,
# Nearest to on: in, referendums, from, info, same, with, through, at,
# Nearest to system: norwood, nara, mikael, our, partners, pls, ravi, bicycle,
# Nearest to has: had, have, is, was, unlucky, cartilage, faber, bronchitis,
# Nearest to who: he, which, also, climatic, and, it, she, jacobian,
# Nearest to which: that, steroid, it, who, crtc, this, bryson, pasadena,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to an: the, herself, presenters, cic, operatorname, doubt, sheave, referenda,
# Nearest to no: utopia, eisa, venona, sacu, commonly, fingering, concerted, bastiat,
# Average loss at step 12000: 3.608076
# Average loss at step 14000: 3.568782
# Average loss at step 16000: 3.409196
# Average loss at step 18000: 3.455582
# Average loss at step 20000: 3.542565
# Nearest to about: darya, hover, feathered, classified, moderator, aroma, preservative, thant,
# Nearest to are: were, is, have, although, was, prophets, yi, giza,
# Nearest to it: he, there, this, they, which, she, intending, not,
# Nearest to other: many, some, various, iguana, wealthy, ribose, these, premiere,
# Nearest to often: also, sometimes, countryside, hilversum, still, doped, there, sondheim,
# Nearest to is: was, has, are, be, snes, if, jeremiah, although,
# Nearest to i: ii, we, crusades, g, whither, stilicho, pencil, partit,
# Nearest to they: he, there, we, it, not, bokassa, she, who,
# Nearest to on: in, at, referendums, through, metaphase, buddhahood, martens, congenital,
# Nearest to system: norwood, bicycle, nara, partners, text, ravi, winnings, transcendence,
# Nearest to has: had, have, is, was, cartilage, adorned, unlucky, incongruous,
# Nearest to who: which, he, she, then, also, they, climatic, there,
# Nearest to which: that, who, this, it, also, there, but, steroid,
# Nearest to six: seven, eight, nine, four, five, three, zero, two,
# Nearest to an: mcgowan, herself, the, acquainted, anger, sheave, doubt, operatorname,
# Nearest to no: sacu, eisa, lyre, fingering, utopia, commonly, venona, not,
# Average loss at step 22000: 3.498002
# Average loss at step 24000: 3.489699
# Average loss at step 26000: 3.480206
# Average loss at step 28000: 3.480289
# Average loss at step 30000: 3.505711
# Nearest to about: darya, hover, thant, schisms, on, feathered, cri, risorgimento,
# Nearest to are: were, have, is, scheele, be, trimester, forbade, although,
# Nearest to it: he, there, this, she, they, which, never, not,
# Nearest to other: various, some, these, wealthy, nephews, ribose, iguana, many,
# Nearest to often: sometimes, also, still, usually, commonly, there, widely, not,
# Nearest to is: was, has, are, be, snes, had, became, does,
# Nearest to i: ii, we, g, actually, crusades, iii, iv, exploited,
# Nearest to they: there, he, we, it, you, who, these, she,
# Nearest to on: in, during, through, upon, referendums, at, from, about,
# Nearest to system: systems, partners, beta, joshi, text, norwood, transcendence, beatboxing,
# Nearest to has: had, have, is, was, cartilage, unlucky, adorned, intensively,
# Nearest to who: she, he, they, which, also, climatic, never, memex,
# Nearest to which: that, this, who, also, steroid, it, crtc, where,
# Nearest to six: four, eight, seven, five, three, nine, two, zero,
# Nearest to an: herself, sheave, mcgowan, operatorname, lina, another, aura, doubt,
# Nearest to no: sacu, eisa, lyre, fingering, utopia, favorably, venona, commonly,
# Average loss at step 32000: 3.505145
# Average loss at step 34000: 3.495387
# Average loss at step 36000: 3.451777
# Average loss at step 38000: 3.304158
# Average loss at step 40000: 3.434865
# Nearest to about: thant, hover, terminal, aroma, junkie, bonds, darya, docking,
# Nearest to are: were, is, have, include, be, although, intermarriages, trimester,
# Nearest to it: he, there, she, this, they, then, which, now,
# Nearest to other: various, different, ribose, some, nephews, several, more, plunder,
# Nearest to often: sometimes, usually, also, still, commonly, generally, widely, largely,
# Nearest to is: was, are, be, has, if, beau, trusts, for,
# Nearest to i: we, ii, you, they, t, he, she, g,
# Nearest to they: we, there, he, you, it, these, she, i,
# Nearest to on: upon, at, othniel, metaphase, during, martens, through, gotha,
# Nearest to system: systems, partners, dissidents, beit, norwood, bicycle, alaskan, ehret,
# Nearest to has: had, have, was, is, cartilage, enveloping, provides, unlucky,
# Nearest to who: he, she, which, also, there, never, often, they,
# Nearest to which: that, this, also, who, crtc, where, now, there,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to an: herself, pipelined, helper, doubt, seinfeld, mcgowan, sheave, anger,
# Nearest to no: sacu, any, fictitious, venona, eisa, lyre, fingering, commonly,
# Average loss at step 42000: 3.435786
# Average loss at step 44000: 3.452850
# Average loss at step 46000: 3.449152
# Average loss at step 48000: 3.358820
# Average loss at step 50000: 3.382026
# Nearest to about: hover, thant, junkie, ptah, feathered, preservative, docking, unomig,
# Nearest to are: were, have, is, include, although, be, smokey, intermarriages,
# Nearest to it: he, there, she, this, they, probably, still, now,
# Nearest to other: various, different, ribose, several, some, many, perturbed, iguana,
# Nearest to often: sometimes, usually, generally, also, still, widely, frequently, commonly,
# Nearest to is: was, has, snes, are, contains, although, mouthpieces, thrash,
# Nearest to i: ii, we, you, t, clashes, g, bokassa, they,
# Nearest to they: he, there, we, she, you, it, these, hauled,
# Nearest to on: upon, around, through, in, panacea, under, referendums, ailey,
# Nearest to system: systems, partners, dissidents, text, bicycle, norwood, beta, beit,
# Nearest to has: had, have, was, is, cartilage, woodward, hymnal, adorned,
# Nearest to who: he, she, which, also, never, actually, there, then,
# Nearest to which: this, that, also, who, what, crtc, there, often,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to an: herself, pipelined, olympia, triplets, mcgowan, operatorname, acquainted, livres,
# Nearest to no: any, sacu, eisa, fictitious, a, venona, traits, biosynthesis,
# Average loss at step 52000: 3.432569
# Average loss at step 54000: 3.427088
# Average loss at step 56000: 3.441380
# Average loss at step 58000: 3.399873
# Average loss at step 60000: 3.398262
# Nearest to about: over, hover, thant, ptah, docking, obtaining, invades, bonds,
# Nearest to are: were, is, have, sulfate, although, these, including, include,
# Nearest to it: he, she, there, this, which, sudetenland, still, that,
# Nearest to other: various, different, many, several, ribose, more, systematically, eschatology,
# Nearest to often: sometimes, usually, generally, also, commonly, still, frequently, now,
# Nearest to is: was, are, has, although, requires, does, snes, became,
# Nearest to i: ii, we, you, si, runic, t, clashes, they,
# Nearest to they: we, there, he, you, she, these, it, would,
# Nearest to on: upon, through, in, janitor, panacea, referendums, under, namibia,
# Nearest to system: systems, dissidents, partners, text, norwood, touchdowns, pls, mode,
# Nearest to has: had, have, was, is, hymnal, having, adorned, cartilage,
# Nearest to who: she, he, never, which, still, actually, memex, synonyms,
# Nearest to which: that, this, what, it, there, however, who, crtc,
# Nearest to six: four, eight, five, seven, nine, three, zero, one,
# Nearest to an: herself, acquainted, triplets, anger, pipelined, lugosi, lina, sheave,
# Nearest to no: any, sacu, fingering, eisa, little, a, organisational, lyre,
# Average loss at step 62000: 3.244021
# Average loss at step 64000: 3.253155
# Average loss at step 66000: 3.399500
# Average loss at step 68000: 3.394252
# Average loss at step 70000: 3.360317
# Nearest to about: over, hover, thant, regarding, unomig, obtaining, junkie, concedes,
# Nearest to are: were, is, these, include, have, including, although, be,
# Nearest to it: he, she, there, this, they, which, still, never,
# Nearest to other: various, different, eschatology, including, accomplices, aap, systematically, many,
# Nearest to often: sometimes, usually, generally, frequently, also, commonly, still, now,
# Nearest to is: was, has, are, snes, be, does, although, became,
# Nearest to i: ii, we, g, you, crusades, guerra, t, bokassa,
# Nearest to they: we, he, there, it, you, she, eventually, these,
# Nearest to on: upon, through, in, within, across, metaphase, around, martens,
# Nearest to system: systems, dissidents, mosley, geckos, norwood, program, situation, partners,
# Nearest to has: had, have, is, was, hymnal, enveloping, cartilage, since,
# Nearest to who: she, which, actually, he, never, still, synonyms, rockville,
# Nearest to which: that, this, also, who, but, what, it, however,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to an: herself, the, anger, operatorname, pipelined, lugosi, livres, sheave,
# Nearest to no: any, sacu, little, commonly, reportedly, aloud, venona, mushroom,
# Average loss at step 72000: 3.373063
# Average loss at step 74000: 3.346343
# Average loss at step 76000: 3.321144
# Average loss at step 78000: 3.353824
# Average loss at step 80000: 3.380644
# Nearest to about: over, hover, junkie, that, napier, thant, feathered, regarding,
# Nearest to are: were, is, have, include, these, although, be, including,
# Nearest to it: he, she, there, this, they, we, probably, itself,
# Nearest to other: various, others, depository, perturbed, aap, western, philosophical, different,
# Nearest to often: sometimes, usually, generally, frequently, still, typically, commonly, also,
# Nearest to is: was, has, are, contains, became, snes, although, includes,
# Nearest to i: ii, g, we, guerra, t, iv, you, clashes,
# Nearest to they: we, he, there, you, she, it, hauled, these,
# Nearest to on: upon, through, in, at, hostage, within, harlequin, under,
# Nearest to system: systems, dissidents, mosley, program, situation, norwood, geckos, network,
# Nearest to has: had, have, is, was, hymnal, enveloping, since, cartilage,
# Nearest to who: he, she, actually, still, never, memex, synonyms, they,
# Nearest to which: that, this, what, usually, also, often, where, actually,
# Nearest to six: four, seven, five, eight, three, nine, zero, two,
# Nearest to an: herself, operatorname, sheave, acquainted, triplets, platter, anger, yang,
# Nearest to no: little, any, bonus, mushroom, ite, reportedly, arrivals, sacu,
# Average loss at step 82000: 3.411488
# Average loss at step 84000: 3.408218
# Average loss at step 86000: 3.393054
# Average loss at step 88000: 3.349898
# Average loss at step 90000: 3.368029
# Nearest to about: regarding, hover, over, junkie, on, thant, obtaining, radioisotopes,
# Nearest to are: were, is, include, although, these, have, gluing, sulfate,
# Nearest to it: he, she, there, this, they, itself, probably, we,
# Nearest to other: various, philosophical, different, others, food, ribose, doctors, cultural,
# Nearest to often: sometimes, usually, generally, commonly, frequently, also, now, typically,
# Nearest to is: was, has, are, although, be, became, requires, snes,
# Nearest to i: ii, we, g, you, t, guerra, iv, v,
# Nearest to they: we, he, there, you, she, it, hauled, soon,
# Nearest to on: upon, through, at, under, in, circumcise, around, about,
# Nearest to system: systems, dissidents, norwood, mosley, situation, network, supreme, transcendence,
# Nearest to has: had, have, is, cartilage, since, was, makes, hymnal,
# Nearest to who: he, she, actually, still, also, never, memex, already,
# Nearest to which: that, this, also, what, usually, often, precautions, both,
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to an: herself, livres, another, yang, acquainted, pipelined, operatorname, lina,
# Nearest to no: any, little, sacu, bonus, abelard, commonly, insulating, only,
# Average loss at step 92000: 3.400130
# Average loss at step 94000: 3.257998
# Average loss at step 96000: 3.362925
# Average loss at step 98000: 3.242528
# Average loss at step 100000: 3.359049
# Nearest to about: hover, feathered, over, regarding, thant, junkie, cri, concedes,
# Nearest to are: were, include, is, although, have, these, while, be,
# Nearest to it: he, she, there, this, they, probably, still, often,
# Nearest to other: various, others, philosophical, different, conspiracy, multiple, mamoru, food,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, now, still,
# Nearest to is: was, has, are, seems, became, snes, contains, be,
# Nearest to i: we, ii, you, g, t, v, they, scar,
# Nearest to they: we, there, he, you, she, it, soon, eventually,
# Nearest to on: upon, through, in, under, at, within, around, against,
# Nearest to system: systems, norwood, mosley, network, program, beta, grotius, dissidents,
# Nearest to has: had, have, is, was, cartilage, since, contains, whereby,
# Nearest to who: he, actually, never, still, she, memex, already, which,
# Nearest to which: that, this, usually, but, what, however, often, typically,
# Nearest to six: seven, five, four, eight, nine, three, zero, two,
# Nearest to an: herself, livres, anger, acquainted, another, mcgowan, lina, yang,
# Nearest to no: little, any, only, biosynthesis, idiomatic, sacu, ite, organisational,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
